# %%
# import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# loading dataset as pandas dataframe
df = pd.read_csv('/content/survey lung cancer.csv')
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL CONSUMING         int64
# COUGHING                  int64
# SHORTNESS OF BREATH       int64
# SWALLOWING DIFFICULTY     int64
# CHEST PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
df.shape
# Out:
# (309, 16)

# %%
total = df.isnull().sum().sort_values(ascending=False)
total
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
# Calculate the percentage influence of each feature
feature_importance_df['Percentage Influence'] = (feature_importance_df['Importance'] /
                                                 feature_importance_df['Importance'].sum()) * 100

# Display the updated DataFrame with percentage influence
feature_importance_df[['Feature', 'Percentage Influence']]
# Out:
#     Feature  Percentage Influence
# 0       AGE                  50.0
# 1  COUGHING                  50.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Menghapus spasi tambahan di semua nama kolom
df.columns = df.columns.str.strip()

# Mengubah nilai di kolom 'LUNG_CANCER' agar lebih deskriptif
df['LUNG_CANCER'] = df['LUNG_CANCER'].map({"YES": "Yes", "NO": "No"})

# Membuat visualisasi
fig, ax = plt.subplots(1, 2, figsize=(14, 6), gridspec_kw={'wspace': 0.3}, facecolor='#f8f9fa')

# Plot distribusi AGE
sns.histplot(df["AGE"], bins=15, color="skyblue", edgecolor="black", ax=ax[0], kde=True)
ax[0].set_title("Distribution of Age", fontsize=14, fontweight='bold')
ax[0].set_xlabel("Age", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].grid(True, linestyle='--', alpha=0.7)

# Plot SMOKING berdasarkan kondisi kanker paru-paru
sns.countplot(x="COUGHING", hue="LUNG_CANCER", data=data, ax=ax[1], palette="viridis")
ax[1].set_title("Coughing: Lung Cancer (Yes vs No)", fontsize=14, fontweight='bold')
ax[1].set_xlabel("Coughing", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].legend(title='Lung Cancer', title_fontsize='13', loc='upper right')
ax[1].grid(True, linestyle='--', alpha=0.7)

# Styling the entire plot layout
plt.suptitle("Lung Cancer Survey Analysis", fontsize=16, fontweight='bold', color='#333333')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# <ipython-input-25-0f6cac02c877>:32: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Menghapus spasi tambahan di semua nama kolom
df.columns = df.columns.str.strip()

# Mengubah nilai di kolom 'LUNG_CANCER' agar lebih deskriptif
df['LUNG_CANCER'] = df['LUNG_CANCER'].map({"YES": "Yes", "NO": "No"})

# Membuat visualisasi
fig, ax = plt.subplots(1, 2, figsize=(14, 6), gridspec_kw={'wspace': 0.3}, facecolor='#f8f9fa')

# Plot distribusi AGE
sns.histplot(df["AGE"], bins=15, color="skyblue", edgecolor="black", ax=ax[0], kde=True)
ax[0].set_title("Distribution of Age", fontsize=14, fontweight='bold')
ax[0].set_xlabel("Age", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].grid(True, linestyle='--', alpha=0.7)

# Plot SMOKING berdasarkan kondisi kanker paru-paru
sns.countplot(x="SMOKING", hue="LUNG_CANCER", data=data, ax=ax[1], palette="viridis")
ax[1].set_title("Smoking: Lung Cancer (Yes vs No)", fontsize=14, fontweight='bold')
ax[1].set_xlabel("Smoking", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].legend(title='Lung Cancer', title_fontsize='13', loc='upper right')
ax[1].grid(True, linestyle='--', alpha=0.7)

# Styling the entire plot layout
plt.suptitle("Lung Cancer Survey Analysis", fontsize=16, fontweight='bold', color='#333333')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# <ipython-input-24-b51a1fd857f6>:32: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Menghapus spasi tambahan di semua nama kolom
df.columns = df.columns.str.strip()

# Mengubah nilai di kolom 'LUNG_CANCER' agar lebih deskriptif
df['LUNG_CANCER'] = df['LUNG_CANCER'].map({"YES": "Yes", "NO": "No"})

# Membuat visualisasi
fig, ax = plt.subplots(1, 2, figsize=(14, 6), gridspec_kw={'wspace': 0.3}, facecolor='#f8f9fa')

# Plot distribusi AGE
sns.histplot(df["AGE"], bins=15, color="skyblue", edgecolor="black", ax=ax[0], kde=True)
ax[0].set_title("Distribution of Age", fontsize=14, fontweight='bold')
ax[0].set_xlabel("Age", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].grid(True, linestyle='--', alpha=0.7)

# Plot SMOKING berdasarkan kondisi kanker paru-paru
sns.countplot(x="FATIGUE", hue="LUNG_CANCER", data=data, ax=ax[1], palette="viridis")
ax[1].set_title("Fatigue: Lung Cancer (Yes vs No)", fontsize=14, fontweight='bold')
ax[1].set_xlabel("Fatigue", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].legend(title='Lung Cancer', title_fontsize='13', loc='upper right')
ax[1].grid(True, linestyle='--', alpha=0.7)

# Styling the entire plot layout
plt.suptitle("Lung Cancer Survey Analysis", fontsize=16, fontweight='bold', color='#333333')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# <ipython-input-26-d28502abd85b>:32: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Menghapus spasi tambahan di nama kolom
df.columns = df.columns.str.strip()

# Menampilkan daftar kolom dalam dataset
print("Columns in the dataset:", df.columns.tolist())

# Membuat plot distribusi AGE yang lebih menarik
plt.figure(figsize=(10, 6), facecolor='#f8f9fa')
sns.histplot(df['AGE'].dropna(), kde=True, color="skyblue", edgecolor="black", bins=20)
plt.title("Distribution of Age", fontsize=16, fontweight='bold', color='#333333')
plt.xlabel("Age", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
# Out:
# Columns in the dataset: ['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY', 'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING', 'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH', 'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER']

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,vars = ['COUGHING','SMOKING','FATIGUE'],
hue="LUNG_CANCER")
plt.show()

# %% [markdown]
# Tabel di atas menunjukkan hubungan antara batuk, merokok, dan kelelahan dengan kanker paru-paru. Dari tabel tersebut dapat dilihat bahwa:
#
# *   Pasien dengan kanker paru-paru lebih cenderung mengalami batuk dan kelelahan daripada pasien tanpa kanker paru-paru.
# *   Tidak terlihat korelasi yang jelas antara merokok dan kanker paru-paru

# %%
# Check if 'Embarked' column exists before mapping values
if 'Embarked' in df.columns:
    df['Embarked'] = df['Embarked'].map({"S": 1, "C": 2, "Q": 2, float('nan'): 0})
else:
    print("Column 'Embarked' not found in DataFrame")

# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
Tcorrelation = numeric_df.corr(method='pearson')
Tcorrelation
# Out:
# Column 'Embarked' not found in DataFrame
#                             AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# AGE                    1.000000 -0.084475        0.005205  0.053170
# SMOKING               -0.084475  1.000000       -0.014585  0.160267
# YELLOW_FINGERS         0.005205 -0.014585        1.000000  0.565829
# ANXIETY                0.053170  0.160267        0.565829  1.000000
# PEER_PRESSURE          0.018685 -0.042822        0.323083  0.216841
# CHRONIC DISEASE       -0.012642 -0.141522        0.041122 -0.009678
# FATIGUE                0.012614 -0.029575       -0.118058 -0.188538
# ALLERGY                0.027990  0.001913       -0.144300 -0.165750
# WHEEZING               0.055011 -0.129426       -0.078515 -0.191807
# ALCOHOL CONSUMING      0.058985 -0.050623       -0.289025 -0.165750
# COUGHING               0.169950 -0.129471       -0.012640 -0.225644
# SHORTNESS OF BREATH   -0.017513  0.061264       -0.105944 -0.144077
# ...

# %%
sns.heatmap(Tcorrelation,xticklabels=Tcorrelation.columns,
 yticklabels=Tcorrelation.columns)
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membaca data dari file CSV
df = pd.read_csv('/content/survey lung cancer.csv')  # Ganti dengan path file Anda

# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

# Menghitung matriks korelasi
correlation_matrix = numeric_df.corr()

# Menampilkan matriks korelasi
print(correlation_matrix)

# Membuat heatmap korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
# Out:
#                             AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# AGE                    1.000000 -0.084475        0.005205  0.053170
# SMOKING               -0.084475  1.000000       -0.014585  0.160267
# YELLOW_FINGERS         0.005205 -0.014585        1.000000  0.565829
# ANXIETY                0.053170  0.160267        0.565829  1.000000
# PEER_PRESSURE          0.018685 -0.042822        0.323083  0.216841
# CHRONIC DISEASE       -0.012642 -0.141522        0.041122 -0.009678
# FATIGUE                0.012614 -0.029575       -0.118058 -0.188538
# ALLERGY                0.027990  0.001913       -0.144300 -0.165750
# WHEEZING               0.055011 -0.129426       -0.078515 -0.191807
# ALCOHOL CONSUMING      0.058985 -0.050623       -0.289025 -0.165750
# COUGHING               0.169950 -0.129471       -0.012640 -0.225644
# SHORTNESS OF BREATH   -0.017513  0.061264       -0.105944 -0.144077
# SWALLOWING DIFFICULTY -0.001270  0.030718        0.345904  0.489403
# ...
